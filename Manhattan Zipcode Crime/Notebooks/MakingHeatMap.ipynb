# %%
import pandas as pd
import shapely
import matplotlib.pyplot as plt
import shapefile
from shapely.geometry import Point
from shapely.geometry import shape
from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm_notebook as tqdm

# %%
shp = shapefile.Reader('ZIP_CODE_040114.shp') #open the shapefile
all_shapes = shp.shapes() # get all the polygons
all_records = shp.records()

# %%
df = pd.read_csv('completezipforecast.csv',index_col=0)

# %%
scaler = MinMaxScaler()

# %%
df[['10001quantity', '10029quantity', '10027quantity',
       '10035quantity', '10002quantity', '10003quantity', '10036quantity',
       '10011quantity', '10025quantity', '10019quantity', '10031quantity',
       '10032quantity', '10013quantity', '10009quantity', '10026quantity',
       '10018quantity', '10012quantity', '10023quantity', '10033quantity',
       '10014quantity', '10016quantity', '10022quantity', '10030quantity',
       '10039quantity', '10024quantity', '10010quantity', '10034quantity',
       '10040quantity', '10017quantity', '10037quantity', '10028quantity',
       '10128quantity', '10007quantity', '10038quantity', '10021quantity',
       '10004quantity', '10020quantity', '10006quantity', '10005quantity',
       '10280quantity', '10044quantity', '10282quantity', '10048quantity',
       '10069quantity', '10111quantity', '10281quantity', '10115quantity']]  = scaler.fit_transform(df[['10001quantity', '10029quantity', '10027quantity',
           '10035quantity', '10002quantity', '10003quantity', '10036quantity',
           '10011quantity', '10025quantity', '10019quantity', '10031quantity',
           '10032quantity', '10013quantity', '10009quantity', '10026quantity',
           '10018quantity', '10012quantity', '10023quantity', '10033quantity',
           '10014quantity', '10016quantity', '10022quantity', '10030quantity',
           '10039quantity', '10024quantity', '10010quantity', '10034quantity',
           '10040quantity', '10017quantity', '10037quantity', '10028quantity',
           '10128quantity', '10007quantity', '10038quantity', '10021quantity',
           '10004quantity', '10020quantity', '10006quantity', '10005quantity',
           '10280quantity', '10044quantity', '10282quantity', '10048quantity',
           '10069quantity', '10111quantity', '10281quantity', '10115quantity']])

# %%
#Subtract scaled values from 1
df[['10001quantity', '10029quantity', '10027quantity',
       '10035quantity', '10002quantity', '10003quantity', '10036quantity',
       '10011quantity', '10025quantity', '10019quantity', '10031quantity',
       '10032quantity', '10013quantity', '10009quantity', '10026quantity',
       '10018quantity', '10012quantity', '10023quantity', '10033quantity',
       '10014quantity', '10016quantity', '10022quantity', '10030quantity',
       '10039quantity', '10024quantity', '10010quantity', '10034quantity',
       '10040quantity', '10017quantity', '10037quantity', '10028quantity',
       '10128quantity', '10007quantity', '10038quantity', '10021quantity',
       '10004quantity', '10020quantity', '10006quantity', '10005quantity',
       '10280quantity', '10044quantity', '10282quantity', '10048quantity',
       '10069quantity', '10111quantity', '10281quantity', '10115quantity']]  = 1-(df[['10001quantity', '10029quantity', '10027quantity',
           '10035quantity', '10002quantity', '10003quantity', '10036quantity',
           '10011quantity', '10025quantity', '10019quantity', '10031quantity',
           '10032quantity', '10013quantity', '10009quantity', '10026quantity',
           '10018quantity', '10012quantity', '10023quantity', '10033quantity',
           '10014quantity', '10016quantity', '10022quantity', '10030quantity',
           '10039quantity', '10024quantity', '10010quantity', '10034quantity',
           '10040quantity', '10017quantity', '10037quantity', '10028quantity',
           '10128quantity', '10007quantity', '10038quantity', '10021quantity',
           '10004quantity', '10020quantity', '10006quantity', '10005quantity',
           '10280quantity', '10044quantity', '10282quantity', '10048quantity',
           '10069quantity', '10111quantity', '10281quantity', '10115quantity']])

# %%
df.to_csv('scaledzipforecast.csv')

# %%
plt.figure(figsize=(8,10))
for n in tqdm(range(770,785)):
    for shape in shp.shapeRecords():
        if shape.record[6] == 'New York':
            x = [i[0] for i in shape.shape.points[:]]
            y = [i[1] for i in shape.shape.points[:]]
        else:
            continue
        plt.plot(x,y, color='w')
        plt.tick_params(axis='both',
                        which='both',      # both major and minor ticks are affected
                        bottom=False,      # ticks along the bottom edge are off
                        left=False,         # ticks along the left edge are off
                        labelbottom=False,
                        labelleft=False)
        plt.title("{}".format(df['date'][n]), fontsize=16, x=0.2,y=0.9)
        
        if shape.record[0] == str(10001):
            plt.fill(x, y, color=([df['10001quantity'][n],df['10001quantity'][n],df['10001quantity'][n]]))
        elif shape.record[0] == str(10029):
            plt.fill(x, y, color=([df['10029quantity'][n],df['10029quantity'][n],df['10029quantity'][n]]))
        elif shape.record[0] == str(10027):
            plt.fill(x, y, color=([df['10027quantity'][n],df['10027quantity'][n],df['10027quantity'][n]]))
        elif shape.record[0] == str(10035):
            plt.fill(x, y, color=([df['10035quantity'][n],df['10035quantity'][n],df['10035quantity'][n]]))
        elif shape.record[0] == str(10002):
            plt.fill(x, y, color=([df['10002quantity'][n],df['10002quantity'][n],df['10002quantity'][n]]))
        elif shape.record[0] == str(10003):
            plt.fill(x, y, color=([df['10003quantity'][n],df['10003quantity'][n],df['10003quantity'][n]]))
        elif shape.record[0] == str(10036):
            plt.fill(x, y, color=([df['10001quantity'][n],df['10001quantity'][n],df['10001quantity'][n]]))
        elif shape.record[0] == str(10011):
            plt.fill(x, y, color=([df['10011quantity'][n],df['10011quantity'][n],df['10011quantity'][n]]))
        elif shape.record[0] == str(10025):
            plt.fill(x, y, color=([df['10025quantity'][n],df['10025quantity'][n],df['10025quantity'][n]]))
        elif shape.record[0] == str(10019):
            plt.fill(x, y, color=([df['10019quantity'][n],df['10019quantity'][n],df['10019quantity'][n]]))
        elif shape.record[0] == str(10031):
            plt.fill(x, y, color=([df['10031quantity'][n],df['10031quantity'][n],df['10031quantity'][n]]))
        elif shape.record[0] == str(10032):
            plt.fill(x, y, color=([df['10032quantity'][n],df['10032quantity'][n],df['10032quantity'][n]]))
        elif shape.record[0] == str(10013):
            plt.fill(x, y, color=([df['10013quantity'][n],df['10013quantity'][n],df['10013quantity'][n]]))
        elif shape.record[0] == str(10009):
            plt.fill(x, y, color=([df['10009quantity'][n],df['10009quantity'][n],df['10009quantity'][n]]))
        elif shape.record[0] == str(10026):
            plt.fill(x, y, color=([df['10026quantity'][n],df['10026quantity'][n],df['10026quantity'][n]]))
        elif shape.record[0] == str(10018):
            plt.fill(x, y, color=([df['10018quantity'][n],df['10018quantity'][n],df['10018quantity'][n]]))
        elif shape.record[0] == str(10012):
            plt.fill(x, y, color=([df['10012quantity'][n],df['10012quantity'][n],df['10012quantity'][n]]))
        elif shape.record[0] == str(10023):
            plt.fill(x, y, color=([df['10023quantity'][n],df['10023quantity'][n],df['10023quantity'][n]]))
        elif shape.record[0] == str(10033):
            plt.fill(x, y, color=([df['10033quantity'][n],df['10033quantity'][n],df['10033quantity'][n]]))
        elif shape.record[0] == str(10014):
            plt.fill(x, y, color=([df['10014quantity'][n],df['10014quantity'][n],df['10014quantity'][n]]))
        elif shape.record[0] == str(10030):
            plt.fill(x, y, color=([df['10030quantity'][n],df['10030quantity'][n],df['10030quantity'][n]]))
        elif shape.record[0] == str(10016):
            plt.fill(x, y, color=([df['10016quantity'][n],df['10016quantity'][n],df['10016quantity'][n]]))
        elif shape.record[0] == str(10022):
            plt.fill(x, y, color=([df['10022quantity'][n],df['10022quantity'][n],df['10022quantity'][n]]))
        elif shape.record[0] == str(10039):
            plt.fill(x, y, color=([df['10039quantity'][n],df['10039quantity'][n],df['10039quantity'][n]]))
        elif shape.record[0] == str(10024):
            plt.fill(x, y, color=([df['10024quantity'][n],df['10024quantity'][n],df['10024quantity'][n]]))
        elif shape.record[0] == str(10010):
            plt.fill(x, y, color=([df['10010quantity'][n],df['10010quantity'][n],df['10010quantity'][n]]))
        elif shape.record[0] == str(10034):
            plt.fill(x, y, color=([df['10034quantity'][n],df['10034quantity'][n],df['10034quantity'][n]]))
        elif shape.record[0] == str(10040):
            plt.fill(x, y, color=([df['10040quantity'][n],df['10040quantity'][n],df['10040quantity'][n]]))
        elif shape.record[0] == str(10017):
            plt.fill(x, y, color=([df['10017quantity'][n],df['10017quantity'][n],df['10017quantity'][n]]))
        elif shape.record[0] == str(10037):
            plt.fill(x, y, color=([df['10037quantity'][n],df['10037quantity'][n],df['10037quantity'][n]]))
        elif shape.record[0] == str(10028):
            plt.fill(x, y, color=([df['10028quantity'][n],df['10028quantity'][n],df['10028quantity'][n]]))
        elif shape.record[0] == str(10128):
            plt.fill(x, y, color=([df['10128quantity'][n],df['10128quantity'][n],df['10128quantity'][n]]))
        elif shape.record[0] == str(10007):
            plt.fill(x, y, color=([df['10007quantity'][n],df['10007quantity'][n],df['10007quantity'][n]]))
        elif shape.record[0] == str(10038):
            plt.fill(x, y, color=([df['10038quantity'][n],df['10038quantity'][n],df['10038quantity'][n]]))
        elif shape.record[0] == str(10021):
            plt.fill(x, y, color=([df['10021quantity'][n],df['10021quantity'][n],df['10021quantity'][n]]))
        elif shape.record[0] == str(10004):
            plt.fill(x, y, color=([df['10004quantity'][n],df['10004quantity'][n],df['10004quantity'][n]]))
        elif shape.record[0] == str(10020):
            plt.fill(x, y, color=([df['10020quantity'][n],df['10020quantity'][n],df['10020quantity'][n]]))
        elif shape.record[0] == str(10006):
            plt.fill(x, y, color=([df['10006quantity'][n],df['10006quantity'][n],df['10006quantity'][n]]))
        elif shape.record[0] == str(10005):
            plt.fill(x, y, color=([df['10005quantity'][n],df['10005quantity'][n],df['10005quantity'][n]]))
        elif shape.record[0] == str(10280):
            plt.fill(x, y, color=([df['10280quantity'][n],df['10280quantity'][n],df['10280quantity'][n]]))
        elif shape.record[0] == str(10044):
            plt.fill(x, y, color=([df['10044quantity'][n],df['10044quantity'][n],df['10044quantity'][n]]))
        elif shape.record[0] == str(10282):
            plt.fill(x, y, color=([df['10282quantity'][n],df['10282quantity'][n],df['10282quantity'][n]]))
        elif shape.record[0] == str(10048):
            plt.fill(x, y, color=([df['10048quantity'][n],df['10048quantity'][n],df['10048quantity'][n]]))
        elif shape.record[0] == str(10069):
            plt.fill(x, y, color=([df['10069quantity'][n],df['10069quantity'][n],df['10069quantity'][n]]))
        elif shape.record[0] == str(10111):
            plt.fill(x, y, color=([df['10111quantity'][n],df['10111quantity'][n],df['10111quantity'][n]]))
        elif shape.record[0] == str(10281):
            plt.fill(x, y, color=([df['10281quantity'][n],df['10281quantity'][n],df['10281quantity'][n]]))
        elif shape.record[0] == str(10115):
            plt.fill(x, y, color=([df['10115quantity'][n],df['10115quantity'][n],df['10115quantity'][n]]))
        else:
            plt.fill(x, y, color=([0.9,0.9,0.9]))

    plt.savefig('map{}.png'.format(n))
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-1dab33899917> in <module>
#      14                         labelbottom=False,
#      15                         labelleft=False)
# ---> 16         plt.title("{}".format(df['date'][n]), fontsize=16, x=0.2,y=0.9)
#      17
#      18         if shape.record[0] == str(10001):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# ...
